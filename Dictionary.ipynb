# %%
d={1:'one',2:'two',3:'Three'}
d
# Out:
# {1: 'one', 2: 'two', 3: 'Three'}

# %%
type(d)
# Out:
# dict

# %%
d1={'one':1,1+2j:2.3,True:0}
d1
# Out:
# {'one': 1, (1+2j): 2.3, True: 0}

# %%
d.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'Three')])

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
d.values()
# Out:
# dict_values(['one', 'two', 'Three'])

# %%
d['four']=[1,2,3]
d
# Out:
# {1: 'one', 2: 'two', 3: 'Three', 'four': [1, 2, 3]}

# %%
d.values()
# Out:
# dict_values(['one', 'two', 'Three', [1, 2, 3]])

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3, 'four'])

# %%
d.pop(1)
d
# Out:
# {2: 'two', 3: 'Three', 'four': [1, 2, 3]}

# %%
d.update()
d
# Out:
# {2: 'two', 3: 'Three', 'four': [1, 2, 3]}

# %%
d[1]='one'
d
# Out:
# {2: 'two', 3: 'Three', 'four': [1, 2, 3], 1: 'one'}

# %%
for i in d:
 print(i)
# Out:
# 2
# 3
# four
# 1

# %%
range d(2,7)
# Out:
#   Cell In[24], line 1
#     range d(2,7)
#           ^
# SyntaxError: invalid syntax

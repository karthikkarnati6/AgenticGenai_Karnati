# %%
5+6
# Out:
# 11

# %%
10*56
# Out:
# 560

# %%
590//5
# Out:
# 118

# %%
200/10
# Out:
# 20.0

# %%
1000/25
# Out:
# 40.0

# %%
print(True+True)
# Out:
# 2

# %%
print(True-False)
# Out:
# 1

# %%
a=1+2j

# %%
b=3+4j

# %%
a+b
# Out:
# (4+6j)

# %%
print(a+b)
# Out:
# (4+6j)

# %%
type(a)
# Out:
# complex

# %%
s1="Welcome to python"
print(s1)
s2="Welcome to NARESHIT"
print(s2)
print(s1==s2)
# Out:
# Welcome to python
# Welcome to NARESHIT
# False

# %%
si='Hell0'

# %%
si[1]
# Out:
# 'e'

# %%
s='welcome to NareshIT'
s
# Out:
# 'welcome to NareshIT'

# %%
s[1:7]
# Out:
# 'elcome'

# %%
s[:]
# Out:
# 'welcome to NareshIT'

# %%
s[2::]
# Out:
# 'lcome to NareshIT'

# %%
s[:10]
# Out:
# 'welcome to'

# %%
s[::2]
# Out:
# 'wloet aehT'

# %%
s[::4]
# Out:
# 'wotah'

# %%
s[::-2]
# Out:
# 'Thea teolw'

# %%
s[::-1]
# Out:
# 'TIhseraN ot emoclew'

# %%
s[1:20:10]
# Out:
# 'eN'

# %%
s[2:20:5]
# Out:
# 'l aI'

# %%
print(s)
# Out:
# welcome to NareshIT

# %%
s[3:20:7]
# Out:
# 'c I'

# %%
s[4:20:3]
# Out:
# 'o  rh'

# %%
s[::-1]
# Out:
# 'TIhseraN ot emoclew'

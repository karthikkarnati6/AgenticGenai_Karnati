# %%
~12
# Out:
# -13

# %%
~23
# Out:
# -24

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(40)
# Out:
# '0b101000'

# %%
35 & 40
# Out:
# 32

# %%
35 | 40
# Out:
# 43

# %%
12 ^ 13
# Out:
# 1

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
25 ^ 30
# Out:
# 7

# %%
~45
# Out:
# -46

# %%
10<<2
# Out:
# 40

# %%
10>>2
# Out:
# 2

# %%
10>>1
# Out:
# 5

# %%
10>>3
# Out:
# 1

# %%
a,b=7,6
print(a)
print(b)
# Out:
# 7
# 6

# %%
a,b=b,a
print(a)
print(b)
# Out:
# 6
# 7

# %%
import math 
math.sqrt(25)
# Out:
# 5.0

# %%
#help(math)

# %%
#help()

# %%
math.floor(4.7)
# Out:
# 4

# %%
math.ceil(4.7)
# Out:
# 5

# %%
import math as m
from math import *
print(m.floor(6.8))
print(m.ceil(6.8))
m.sqrt(56)
m.pow(55,2)
# Out:
# 6
# 7
# 3025.0

# %%
input()
# Out:
#  2
# '2'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  7
#  8
# 78

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
x1=int(input("enter Ist number"))
y1=int(input("enter 2nd number"))
z1=x1+y1
print(z1)
# Out:
# enter Ist number 7
# enter 2nd number 9
# 16

# %%
st=input('Enter a name')
print(st)
# Out:
# Enter a name nareshit
# nareshit

# %%
print(st[0])
# Out:
# n

# %%
print(st[2:5])
# Out:
# res

# %%
print(st[-2])
# Out:
# i

# %%
st=input('enter a string')[1]
print(st)
# Out:
# enter a string karthik
# a

# %%
st=input('Enter PAN number')[4:]
print(st)
# Out:
# Enter PAN number CLOPK3075Q
# K3075Q

# %%
mat=eval(input('Enter problem'))
print(mat)
# Out:
# Enter problem 2+3-1
# 4

# %%
l=[]
l
# Out:
# []

# %%
print(len(l))
# Out:
# 0

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
id(l)
# Out:
# 1526239468672

# %%
l.append(10)

# %%
l
# Out:
# [10, 10, 10, 20, 30, 40, 10, 20, 30, 40]

# %%
l.remove(10)
l.remove(10)

# %%
l
# Out:
# [20, 30, 40, 10, 20, 30, 40]

# %%
l.append([20,30,40])

# %%
l
# Out:
# [20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
l1=[1,3.4,1+2j,'karthik']

# %%
l3=[20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l3=l1.copy()

# %%
l3
# Out:
# [1, 3.4, (1+2j), 'karthik']

# %%
l[:]
# Out:
# [1, 3.4, (1+2j), 'karthik']

# %%
l[:-1]
# Out:
# [1, 3.4, (1+2j)]

# %%
l[::-1]
# Out:
# ['karthik', (1+2j), 3.4, 1]

# %%
l
l1
# Out:
# [1, 3.4, (1+2j), 'karthik']

# %%
l
l1
l3
# Out:
# [20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
l3=[20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
l3[::4]
# Out:
# [20, 20]

# %%
l3[:4]
# Out:
# [20, 30, 40, 10]

# %%
l3[::-3]
# Out:
# [[20, 30, 40], 20, 30]

# %%
l3[::-1]
# Out:
# [[20, 30, 40], 40, 30, 20, 10, 40, 30, 20]

# %%
l3[::-2]
# Out:
# [[20, 30, 40], 30, 10, 30]

# %%
l3[::-3]
# Out:
# [[20, 30, 40], 20, 30]

# %%
l3.count(30)
# Out:
# 2

# %%
l3=[20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
[1, 3.4, (1+2j), 'karthik']

# %%
l2[::-2]
# Out:
# ['karthik', 3.4]

# %%
l2[::-1]
# Out:
# ['karthik', (1+2j), 3.4, 1]

# %%
l2.count(3.4)
# Out:
# 1

# %%
print(l3)
# Out:
# [20, 30, 40, 10, 20, 30, 40, [20, 30, 40]]

# %%
bool(l2)
# Out:
# True

# %%
bool(l3)
# Out:
# True

# %%
l3.reverse()
l3
# Out:
# [[20, 30, 40], 40, 30, 20, 10, 40, 30, 20]

# %%
l3.index(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l3.index(40)
#
# NameError: name 'l3' is not defined

# %%
l1=[10,20,40,30,15]
l1.sort(reverse=True)
print(l1)
# Out:
# [40, 30, 20, 15, 10]

# %%
len(l1)
# Out:
# 5

# %%
l2=[1, 3.4, (1+2j), 'karthik']

# %%
l1
# Out:
# [40, 30, 20, 15, 10]

# %%
l2
# Out:
# [1, 3.4, (1+2j), 'karthik']

# %%
l1.extend(l2)

# %%
l1
# Out:
# [40, 30, 20, 15, 10, 1, 3.4, (1+2j), 'karthik']

# %%
l1.index(15)
# Out:
# 3

# %%
l1.index(True)
# Out:
# 5

# %%
l1.index('karthik')
# Out:
# 8

# %%
l1.extend(range(3))
l1
# Out:
# [40, 30, 20, 15, 10, 1, 3.4, (1+2j), 'karthik', 0, 1, 2, 0, 1, 2]

# %%
l1.insert(4,70)
l1
# Out:
# [40, 30, 20, 15, 70, 10, 1, 3.4, (1+2j), 'karthik', 0, 1, 2, 0, 1, 2, 4, 4]

# %%
l1.pop()
l1
# Out:
# [40, 30, 20, 15, 70, 10, 1, 3.4, (1+2j), 'karthik', 0, 1, 2, 0, 1, 2]

# %%
l1.pop(5)
l1
# Out:
# [40, 30, 20, 15, 70, 1, 3.4, (1+2j), 'karthik', 0, 1, 2, 0, 1, 2]

# %%
l1.remove(2)
l1
# Out:
# [40, 30, 20, 15, 70, 1, 3.4, (1+2j), 'karthik', 0, 1, 0, 1]

# %%
15 in l1
# Out:
# True

# %%
30 in l2
# Out:
# False

# %%
l1.reverse()
l1
# Out:
# [40, 30, 20, 15, 70, 3.4, (1+2j), 'karthik', 0, 1, 0, 1]

# %%
l1.remove(1)

# %%
l1
# Out:
# [40, 30, 20, 15, 70, 3.4, (1+2j), 'karthik', 0, 1, 0, 1]

# %%
l2.reverse()

# %%
l2
# Out:
# ['karthik', (1+2j), 3.4, 1]

# %%
l1.reverse()
l1
# Out:
# [1, 0, 1, 0, 'karthik', (1+2j), 3.4, 70, 15, 20, 30, 40]

# %%
l3=[40, 30, 20, 15, 10]
l3.sort()
l3
# Out:
# [10, 15, 20, 30, 40]

# %%
l3.sort(reverse=True)
l3
# Out:
# [40, 30, 20, 15, 10]

# %%
for i in l1:
    print(i)
# Out:
# 3.4
# 15
# 20
# 30
# 40
# 70
# (1+2j)
# karthik
# 0
# 1
# 0
# 1
